# %% [markdown]
# <div align=right> <font color='darkblue'>Test Basthon #2 CLOUD (ND)</font></div>
#
# ----
#
# ## <font color="darkblue">L'instruction `print` : afficher à l'écran</font>
# Le traditionnel "Hello world"...

# %%
print("Bonjour")
